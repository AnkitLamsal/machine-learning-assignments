# %% [markdown]
# # Exploratory Data Analysis of Campaign Sales Dataset
#
# In this Assignment, We have used following libraries:
#
# 1. Pandas
# 2. Matplotlib
# 3. Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Reading the Dataset

# %%
df = pd.read_csv("AddedFeatures_campaign_sale.csv")

# %% [markdown]
# # Descriptive Statistics of The dataset
#
#
# Following are the statistics used in the datasets:
#
# `.head()` -  For Viewing 5 rows in all columns<br>
# `.info()` - For Getting Descriptions of Null Objects<br>
# `.describe()` - For Getting *Mean, Standard Deviation and other statistics* for categorical and numerical values.

# %%
df.head()
# Out:
#    Index  Campaign Period Sales  Buy  Historical Sales Volume  \
# 0      0             238.704762    1            146803.428571
# 1      1             281.680000    1            439984.160000
# 2      2             432.857143    1            970465.714286
# 3      3               0.000000    0            230193.600000
# 4      4             308.419048    1            182584.076190
#
#    Number of Prior Year Transactions  Number of Transactions  \
# 0                                 15                      15
# 1                                 22                      22
# 2                                 19                      19
# 3                                 17                      17
# 4                                 16                      16
#
#    Purchase Breadth  Customer_engagement_days  Days_since_last_transaction  \
# 0                 2                     19170                         2242
# 1                 1                     14530                         2368
# 2                 1                     21331                         4028
# 3                 1                     13814                         2417
# 4                 2                     15292                         3137
#
#   Customer_engagement_length  ... Email Available   Desk Executive Chair  \
# 0                  Long-term  ...            True  False           False
# 1                  Long-term  ...            True  False           False
# 2                  Long-term  ...            True  False           False
# 3                   Mid-term  ...            True  False           False
# 4                  Long-term  ...           False  False           False
#
#   Standard Chair Monitor  Printer  Computer  Insurance  Toner  Office Supplies
# 0          False   False    False     False       True  False             True
# 1          False   False    False     False      False  False             True
# 2          False   False    False     False      False  False             True
# 3          False   False    False     False      False  False             True
# 4          False   False    False     False      False   True             True
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12132 entries, 0 to 12131
# Data columns (total 26 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Index                              12132 non-null  int64
#  1   Campaign Period Sales              12132 non-null  float64
#  2   Buy                                12132 non-null  int64
#  3   Historical Sales Volume            12132 non-null  float64
#  4   Number of Prior Year Transactions  12132 non-null  int64
#  5   Number of Transactions             12132 non-null  int64
#  6   Purchase Breadth                   12132 non-null  int64
#  7   Customer_engagement_days           12132 non-null  int64
#  8   Days_since_last_transaction        12132 non-null  int64
#  9   Customer_engagement_length         12132 non-null  object
#  10  Language_group                     12132 non-null  object
#  11  Repurchase Method                  12132 non-null  object
#  12  Last Transaction Channel           12132 non-null  object
#  13  Number of Employees                12132 non-null  object
#  14  Service Level                      12132 non-null  object
#  15  Do No Disturb                      12132 non-null  bool
#  16  Email Available                    12132 non-null  bool
#  17  Desk                               12132 non-null  bool
#  18  Executive Chair                    12132 non-null  bool
#  19  Standard Chair                     12132 non-null  bool
#  20  Monitor                            12132 non-null  bool
#  21  Printer                            12132 non-null  bool
#  22  Computer                           12132 non-null  bool
#  23  Insurance                          12132 non-null  bool
#  24  Toner                              12132 non-null  bool
#  25  Office Supplies                    12132 non-null  bool
# dtypes: bool(11), float64(2), int64(7), object(6)
# memory usage: 1.5+ MB

# %%
df.describe(include = ['O'])
# Out:
#        Customer_engagement_length Language_group Repurchase Method  \
# count                       12132          12132             12132
# unique                          3              4                 2
# top                      Mid-term        English            NOTICE
# freq                         8577          10978              9108
#
#        Last Transaction Channel Number of Employees Service Level
# count                     12132               12132         12132
# unique                        8                   6             2
# top                        MAIL                6-10       Premier
# freq                       6255                5111          6985

# %%
df.describe(include=[np.number])
# Out:
#               Index  Campaign Period Sales           Buy  \
# count  12132.000000           12132.000000  12132.000000
# mean    6065.500000             107.933384      0.270936
# std     3502.351067             267.200455      0.444462
# min        0.000000               0.000000      0.000000
# 25%     3032.750000               0.000000      0.000000
# 50%     6065.500000               0.000000      0.000000
# 75%     9098.250000             137.278000      1.000000
# max    12131.000000            5927.306667      1.000000
#
#        Historical Sales Volume  Number of Prior Year Transactions  \
# count             1.213200e+04                       12132.000000
# mean              5.600768e+05                          16.512117
# std               7.039575e+05                           6.034094
# min               0.000000e+00                           1.000000
# 25%               1.792572e+05                          13.000000
# 50%               3.678030e+05                          18.000000
# 75%               6.921952e+05                          20.000000
# max               1.648348e+07                          64.000000
#
#        Number of Transactions  Purchase Breadth  Customer_engagement_days  \
# count            12132.000000      12132.000000              12132.000000
# mean                16.500412          1.255358              10297.605589
# std                  6.040510          0.751494               3969.253480
# min                  1.000000          0.000000               1033.000000
# 25%                 13.000000          1.000000               8670.000000
# 50%                 18.000000          1.000000              10055.000000
# 75%                 20.000000          1.000000              12323.000000
# max                 64.000000          9.000000              34770.000000
#
#        Days_since_last_transaction
# count                 12132.000000
# mean                   3009.300363
# std                     794.941745
# min                     934.000000
# 25%                    2431.000000
# 50%                    2925.000000
# 75%                    3436.000000
# max                    6827.000000

# %% [markdown]
# ### Looking out Shape, Columns and Index of the dataset,
# ### Also, looking for Numerical, Binary and Categorical Columns

# %%
df.shape
# Out:
# (12132, 26)

# %%
df.columns
# Out:
# Index(['Index', 'Campaign Period Sales', 'Buy', 'Historical Sales Volume',
#        'Number of Prior Year Transactions', 'Number of Transactions',
#        'Purchase Breadth', 'Customer_engagement_days',
#        'Days_since_last_transaction', 'Customer_engagement_length',
#        'Language_group', 'Repurchase Method', 'Last Transaction Channel',
#        'Number of Employees', 'Service Level', 'Do No Disturb',
#        'Email Available', 'Desk', 'Executive Chair', 'Standard Chair',
#        'Monitor', 'Printer', 'Computer', 'Insurance', 'Toner',
#        'Office Supplies'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=12132, step=1)

# %%
# Looking for categorical and Numerical features

print("Categorical Features of dataset:"+ str(len([i for i in df.columns if df[i].dtype == object])))
print("Floating Type Numerical Features of dataset:"+ str(len([i for i in df.columns if df[i].dtype == float])))
print("Integer Type Numerical Fetaures of dataset:"+str(len([i for i in df.columns if df[i].dtype == np.int64()])))
# Out:
# Categorical Features of dataset:6
# Floating Type Numerical Features of dataset:2
# Integer Type Numerical Fetaures of dataset:7

# %% [markdown]
# # Graphical Visualization
#
# Following Visualization is done below:
#
# 1. Correlation Matrix with Heatmap (Using Seaborn)
# 2. Bar Plot for Binary and Categorical Columns.
# 3. Histogram for Numerical Datas.
# 4. Scatter plot for Number of Prior Transaction and Days Since Last Transaction.
# 5. Boxplot for numerical Columns.
# 6. Pie Plot for categorical columns.

# %%
df.select_dtypes(include = np.number).corr()
# Out:
#                                       Index  Campaign Period Sales       Buy  \
# Index                              1.000000               0.001261 -0.013117
# Campaign Period Sales              0.001261               1.000000  0.662652
# Buy                               -0.013117               0.662652  1.000000
# Historical Sales Volume           -0.004947               0.244359 -0.037849
# Number of Prior Year Transactions  0.002379               0.009634  0.012715
# Number of Transactions             0.002455              -0.000169  0.010751
# Purchase Breadth                  -0.001689               0.200286  0.073704
# Customer_engagement_days          -0.022896               0.122734  0.287892
# Days_since_last_transaction        0.019369               0.112299 -0.089226
#
#                                    Historical Sales Volume  \
# Index                                            -0.004947
# Campaign Period Sales                             0.244359
# Buy                                              -0.037849
# Historical Sales Volume                           1.000000
# Number of Prior Year Transactions                 0.290526
# Number of Transactions                            0.290253
# Purchase Breadth                                  0.162203
# Customer_engagement_days                         -0.061855
# Days_since_last_transaction                       0.306673
#
#                                    Number of Prior Year Transactions  \
# Index                                                       0.002379
# Campaign Period Sales                                       0.009634
# Buy                                                         0.012715
# Historical Sales Volume                                     0.290526
# Number of Prior Year Transactions                           1.000000
# Number of Transactions                                      0.994900
# Purchase Breadth                                            0.131569
# Customer_engagement_days                                    0.026211
# Days_since_last_transaction                                -0.004711
#
#                                    Number of Transactions  Purchase Breadth  \
# Index                                            0.002455         -0.001689
# Campaign Period Sales                           -0.000169          0.200286
# Buy                                              0.010751          0.073704
# Historical Sales Volume                          0.290253          0.162203
# Number of Prior Year Transactions                0.994900          0.131569
# Number of Transactions                           1.000000          0.129472
# Purchase Breadth                                 0.129472          1.000000
# Customer_engagement_days                         0.026189          0.070417
# Days_since_last_transaction                     -0.005682          0.023996
#
#                                    Customer_engagement_days  \
# Index                                             -0.022896
# Campaign Period Sales                              0.122734
# Buy                                                0.287892
# Historical Sales Volume                           -0.061855
# Number of Prior Year Transactions                  0.026211
# Number of Transactions                             0.026189
# Purchase Breadth                                   0.070417
# Customer_engagement_days                           1.000000
# Days_since_last_transaction                       -0.128927
#
#                                    Days_since_last_transaction
# Index                                                 0.019369
# Campaign Period Sales                                 0.112299
# Buy                                                  -0.089226
# Historical Sales Volume                               0.306673
# Number of Prior Year Transactions                    -0.004711
# Number of Transactions                               -0.005682
# Purchase Breadth                                      0.023996
# Customer_engagement_days                             -0.128927
# Days_since_last_transaction                           1.000000

# %%
sns.heatmap(df.select_dtypes(include = np.number).corr(), 
            vmin=-1, vmax=1, center=0)

# %%
plt.figure(figsize = (3,3))
for category in df.select_dtypes(include = ["O", bool]):
    df[category].value_counts().plot(kind = "bar")
    plt.show()

# %%
fig = plt.figure(figsize = (15,15))
ax = fig.gca()
df.select_dtypes(include = np.number).hist(ax = ax)
plt.show()
# Out:
# <ipython-input-14-0f3d4e113022>:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   df.select_dtypes(include = np.number).hist(ax = ax)

# %%
plt.scatter(df['Number of Prior Year Transactions'], df['Days_since_last_transaction'])
plt.xlabel("previous year transaction")
plt.ylabel("Last Transaction Days")
plt.show()

# %%
fig = plt.figure(figsize = (5,5))
plt.tight_layout()
for category in df.select_dtypes(include = ["O"] ):
    df[category].value_counts().plot(kind='pie')
    plt.show()

# %% [markdown]
# # Data Quality Verification
#
# This Segment looks out for Data Quality.
#
# 1. Outlier Data (Shown in Box Plot)
# 2. Missing Data
# 3. Imbalance Data

# %%
fig = plt.figure(figsize = (1,1))


for category in df.select_dtypes(include = [np.number] ):
#     print(type(category))
    df.boxplot(column = category)
    plt.show()

# %%
pd.isnull(df).sum()
# Out:
# Index                                0
# Campaign Period Sales                0
# Buy                                  0
# Historical Sales Volume              0
# Number of Prior Year Transactions    0
# Number of Transactions               0
# Purchase Breadth                     0
# Customer_engagement_days             0
# Days_since_last_transaction          0
# Customer_engagement_length           0
# Language_group                       0
# Repurchase Method                    0
# Last Transaction Channel             0
# Number of Employees                  0
# Service Level                        0
# Do No Disturb                        0
# Email Available                      0
# Desk                                 0
# Executive Chair                      0
# Standard Chair                       0
# Monitor                              0
# Printer                              0
# Computer                             0
# Insurance                            0
# Toner                                0
# Office Supplies                      0
# dtype: int64
